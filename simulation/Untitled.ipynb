# %%
import pandas as pd
import numpy as np

# %%
t = pd.read_table("/Users/Christa.Caggiano/Desktop/zaitlen_lab_desktop/als1_common_header.txt")

# %%
t = t.replace(to_replace=".", value=np.nan)

# %%
t.fillna(t.mean())
# Out:
#          chr      start        end  meth  unmeth  total chr.1    start.1  \
# 0       chr1      13079      13080     6       0      6  chr1      13079
# 1       chr1      51936      51937     6       1      7  chr1      51936
# 2       chr1      51954      51955     8       0      8  chr1      51954
# 3       chr1      51970      51971     5       2      7  chr1      51970
# 4       chr1      51976      51977     7       0      7  chr1      51976
# 5       chr1      51979      51980     6       0      6  chr1      51979
# 6       chr1      52016      52017     8       1      9  chr1      52016
# 7       chr1      52034      52035     9       1     10  chr1      52034
# 8       chr1      54489      54490     1       1      2  chr1      54489
# 9       chr1      54490      54491     4       1      5  chr1      54490
# 10      chr1      58447      58448    14       2     16  chr1      58447
# 11      chr1      58448      58449     9       1     10  chr1      58448
# ...

# %%
df.apply(lambda x: x.fillna(x.mean()),axis=0)
